# %% [markdown]
# ### Scraping Yahoo Finance Stock

# %%
import requests
from bs4 import BeautifulSoup
import time
import random

# %%
yahoo_stocks = []

stock_list = ['NVDA', 'AMZN', 'LCID', 'VALE', 'INTC', 'TSLA', 'AAPL', 'SOFI', 'NIO', 'AMD']
for stocks in stock_list:
    url = f'https://finance.yahoo.com/quote/{stocks}'
    headers_list = [
        {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/125.0.0.0 Safari/537.36'},
        {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 13_5) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/17.0 Safari/605.1.15'},
        {'User-Agent': 'Mozilla/5.0 (iPhone; CPU iPhone OS 17_0 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/17.0 Mobile/15E148 Safari/604.1'},
        {'User-Agent': 'Mozilla/5.0 (Linux; Android 14; SM-G998B) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/125.0.0.0 Mobile Safari/537.36'},
        {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/125.0.0.0 Safari/537.36 Edg/125.0.0.0'}
    ]

    headers = random.choice(headers_list)

    try:
        r = requests.get(url, headers=headers)
        #print(r.status_code)

        soup = BeautifulSoup(r.text, 'html.parser')

        stock = soup.select_one('h1.yf-4vbjci')
        price = soup.select_one('span[data-testid="qsp-price"]')
        change = soup.select_one('span[data-testid="qsp-price-change"]')

        yahoo_stock = {
            'stock': stock.text if stock else 'N/A',
            'price': price.text.strip() if price else 'N/A',
            'change': change.text.strip() if change else 'N/A'
        }

    except Exception as e:
        print(f'Error scraping {stocks}: {e}')
        yahoo_stock = {
            'stock': stocks,
            'price': 'Error',
            'change': 'Error'
        }
    yahoo_stocks.append(yahoo_stock)

print(yahoo_stocks)
# Out:
# [{'stock': 'NVIDIA Corporation (NVDA)', 'price': '173.72', 'change': '-4.15'}, {'stock': 'Amazon.com, Inc. (AMZN)', 'price': '214.75', 'change': '-19.36'}, {'stock': 'Lucid Group, Inc. (LCID)', 'price': '2.4200', 'change': '-0.0400'}, {'stock': 'Vale S.A. (VALE)', 'price': '9.71', 'change': '+0.18'}, {'stock': 'N/A', 'price': 'N/A', 'change': 'N/A'}, {'stock': 'Tesla, Inc. (TSLA)', 'price': '302.63', 'change': '-5.64'}, {'stock': 'Apple Inc. (AAPL)', 'price': '202.38', 'change': '-5.19'}, {'stock': 'SoFi Technologies, Inc. (SOFI)', 'price': '21.58', 'change': '-1.00'}, {'stock': 'NIO Inc. (NIO)', 'price': '5.01', 'change': '+0.14'}, {'stock': 'Advanced Micro Devices, Inc. (AMD)', 'price': '171.70', 'change': '-4.61'}]

# %%
import pandas as pd

# %%
df = pd.DataFrame(yahoo_stocks)

# %%
df
# Out:
#                                 stock   price   change
# 0           NVIDIA Corporation (NVDA)  173.72    -4.15
# 1             Amazon.com, Inc. (AMZN)  214.75   -19.36
# 2            Lucid Group, Inc. (LCID)  2.4200  -0.0400
# 3                    Vale S.A. (VALE)    9.71    +0.18
# 4                                 N/A     N/A      N/A
# 5                  Tesla, Inc. (TSLA)  302.63    -5.64
# 6                   Apple Inc. (AAPL)  202.38    -5.19
# 7      SoFi Technologies, Inc. (SOFI)   21.58    -1.00
# 8                      NIO Inc. (NIO)    5.01    +0.14
# 9  Advanced Micro Devices, Inc. (AMD)  171.70    -4.61

# %%
df.to_csv('yahoo_finance_active_stock.csv', index=False)
